# %% [markdown]
# # Day 2｜AI 商品組合優化、品類管理與供應規劃
#
# ## 從商品績效到可執行組合策略
#
# > **資料使用邊界：** 本 Notebook 使用固定亂數種子產生的教學虛擬資料，不是任何企業的真實營運資料。結果只能用於練習分析流程，不可宣稱為企業事實或因果效果。
#
# ### 故事情境
#
# 第二天，四家企業都遇到『選項太多』：雜草町的手作課程各有支持者；義大的套票跨越購物、飯店與樂園；盛香珍有口味、包裝與通路組合；寶島眼鏡則有鏡框、鏡片、健康服務與會員方案。主管問：哪些負責引流、哪些負責獲利、哪些值得培養、哪些需要調整？
#
# ### 今日決策問題
#
# **如何用多指標探索商品／服務組合，並在容量、庫存與企業定位限制下分配角色？**
#
# ### 學習目標
#
# - 能建立營收、毛利、成長、波動與週轉／容量指標
# - 能說明標準化對距離分群的重要性
# - 能執行 KMeans 並比較群數
# - 能用 PCA 觀察群集而不做因果宣稱
# - 能由群集輪廓人工命名商品角色
#
# ### Colab 操作提醒
#
# 1. 在 Google Drive 建立個人副本。
# 2. 將對應 CSV 上傳到 Colab `/content`，或保持教材包原始相對路徑。
# 3. 由上到下依序執行；若 Runtime 重啟，請重新執行全部儲存格。
# 4. 每個程式碼儲存格後都有繁體中文說明、預期輸出與完成檢核。

# %% [markdown]
# ### [D2-S01] 載入商品組合月資料

# %%
# 本格目的：載入套件並找到教學資料檔
from pathlib import Path
import warnings

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option("display.max_columns", 50)
pd.set_option("display.float_format", lambda x: f"{x:,.3f}")
sns.set_theme(style="whitegrid")

# 優先從公開 GitHub Raw 讀取資料；失敗時再使用 /content 或本機相對路徑
import os

RAW_DATA_URL = "https://raw.githubusercontent.com/johnnychao/mcut-m4-business-analytics-2026-student/main/docs/resources/data/day-2-product-portfolio.csv"
DATA_FILENAME = "day-2-product-portfolio.csv"
LOCAL_FALLBACK_NAMES = [DATA_FILENAME, "day2_product_portfolio.csv"]
FORCE_LOCAL_DATA = os.environ.get("M4_FORCE_LOCAL_DATA") == "1"

try:
    # 正式教材 QA 會刻意關閉遠端來源，確認 ../04_data 備援路徑可獨立運作
    if FORCE_LOCAL_DATA:
        raise ConnectionError("M4 Notebook QA：改用本機資料備援")
    df = pd.read_csv(RAW_DATA_URL)
    data_source = RAW_DATA_URL
except Exception as remote_error:
    candidate_paths = []
    for filename in LOCAL_FALLBACK_NAMES:
        candidate_paths.extend([
            Path("/content") / filename,
            Path(filename),
            Path("../04_data") / filename,
            Path("../04_虛擬資料") / filename,
        ])
    data_path = next((path for path in candidate_paths if path.exists()), None)
    if data_path is None:
        raise FileNotFoundError(
            f"GitHub Raw 暫時無法讀取，而且 /content 也找不到 {DATA_FILENAME}。"
        ) from remote_error
    df = pd.read_csv(data_path)
    data_source = str(data_path)

# 所有課堂匯出檔集中放在 outputs，避免散落在 Notebook 旁
OUTPUT_DIR = Path("outputs")
OUTPUT_DIR.mkdir(exist_ok=True)

print(f"資料來源：{data_source}")
print(f"資料尺寸：{df.shape}")
display(df.head(3))
# Out:
# 資料來源：..\04_data\day-2-product-portfolio.csv
# 資料尺寸：(960, 16)
#         month company  offer_id      offer category channel  units_sold  \
# 0  2025-01-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          35
# 1  2025-02-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          16
# 2  2025-03-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          29
#
#    capacity_units  price  unit_cost  repeat_rate  satisfaction  growth_rate  \
# 0              63    922        313        0.222         3.600       -0.123
# 1              26    922        313        0.114         3.360       -0.107
# 2              56    922        313        0.081         2.990       -0.045
#
#    lead_time_days  is_service  is_synthetic
# 0               7           1          True
# 1               7           1          True
# 2               3           1          True

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 載入資料並確認 Colab 或教材包路徑。
# - **預期輸出：** 資料尺寸與前三列。
# - **完成檢核：** 資料約 960 列，且有 `is_synthetic`。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S02] 檢查資料並選定單一企業

# %%
# 本格目的：處理日期、缺失與企業篩選
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

assert df["is_synthetic"].astype(str).str.lower().eq("true").all()
df["month"] = pd.to_datetime(df["month"], errors="coerce")
for col in ["repeat_rate", "satisfaction"]:
    df[col] = df.groupby("company")[col].transform(lambda s: s.fillna(s.median()))

# TODO：請改成你組負責的企業名稱
SELECTED_COMPANY = "雜草町"
company_df = df.loc[df["company"] == SELECTED_COMPANY].copy()
assert company_df["company"].nunique() == 1 and not company_df.empty
print("資料筆數：", len(company_df))
print("商品／服務數：", company_df["offer_id"].nunique())
display(company_df.head(3))
# Out:
# 資料筆數： 240
# 商品／服務數： 20
#        month company  offer_id      offer category channel  units_sold  \
# 0 2025-01-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          35
# 1 2025-02-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          16
# 2 2025-03-01     雜草町  D2-01-01  手捏陶體驗-方案1    手捏陶體驗      線上          29
#
#    capacity_units  price  unit_cost  repeat_rate  satisfaction  growth_rate  \
# 0              63    922        313        0.222         3.600       -0.123
# 1              26    922        313        0.114         3.360       -0.107
# 2              56    922        313        0.081         2.990       -0.045
#
#    lead_time_days  is_service  is_synthetic
# 0               7           1          True
# 1               7           1          True
# 2               3           1          True

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 確認虛擬標記、補足兩個教學缺失欄，並將資料限制在一家企業。
# - **預期輸出：** 240 列月資料與 20 個商品／服務。
# - **完成檢核：** 企業唯一值為 1，offer_id 唯一值為 20。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S03] 建立商品／服務 KPI 輪廓

# %%
# 本格目的：把月資料彙總成每個商品／服務的一列決策輪廓
company_df["revenue"] = company_df["units_sold"] * company_df["price"]
company_df["gross_profit"] = company_df["units_sold"] * (company_df["price"] - company_df["unit_cost"])

portfolio = company_df.groupby(["offer_id", "offer", "category"], as_index=False).agg(
    units_sold=("units_sold", "sum"),
    capacity_units=("capacity_units", "sum"),
    revenue=("revenue", "sum"),
    gross_profit=("gross_profit", "sum"),
    repeat_rate=("repeat_rate", "mean"),
    satisfaction=("satisfaction", "mean"),
    growth_rate=("growth_rate", "mean"),
    lead_time_days=("lead_time_days", "mean"),
    monthly_std=("units_sold", "std"),
)
portfolio["gross_margin_rate"] = portfolio["gross_profit"] / portfolio["revenue"]
portfolio["resource_utilization"] = portfolio["units_sold"] / portfolio["capacity_units"]
portfolio["demand_volatility"] = portfolio["monthly_std"] / portfolio["units_sold"].div(12)
display(portfolio.sort_values("gross_profit", ascending=False).head(10).round(3))
# Out:
#     offer_id       offer category  units_sold  capacity_units  revenue  \
# 4   D2-01-05   手捏陶體驗-方案2    手捏陶體驗        1061            1299  1575585
# 9   D2-01-10   羊毛氈課程-方案3    羊毛氈課程        1089            1315  1617165
# 8   D2-01-09   手捏陶體驗-方案3    手捏陶體驗         984            1292  1322496
# 19  D2-01-20  老宅夜間工藝-方案5   老宅夜間工藝        1198            1506  1779030
# 14  D2-01-15    金工入門-方案4     金工入門         992            1208  1473120
# 13  D2-01-14   羊毛氈課程-方案4    羊毛氈課程         950            1230  1276800
# 12  D2-01-13   手捏陶體驗-方案4    手捏陶體驗         794            1124   955182
# 3   D2-01-04  老宅夜間工藝-方案1   老宅夜間工藝         941            1222  1264704
# 18  D2-01-19    金工入門-方案5     金工入門         809            1116  1087296
# 17  D2-01-18   羊毛氈課程-方案5    羊毛氈課程         747            1089   898641
#
#     gross_profit  repeat_rate  satisfaction  growth_rate  lead_time_days  \
# 4        1039780        0.443         4.071        0.078          21.583
# 9         970299        0.427         4.128        0.077          20.833
# 8         872808        0.375         3.910        0.053          16.917
# 19        854174        0.451         4.077        0.087          21.083
# 14        795584        0.426         4.198        0.085          20.417
# 13        765700        0.366         3.858        0.051          17.000
# 12        630436        0.300         3.756       -0.001          12.667
# 3         606945        0.378         3.986        0.038          17.083
# 18        587334        0.367         3.908        0.051          16.833
# 17        539334        0.307         3.672       -0.008          13.667
#
#     monthly_std  gross_margin_rate  resource_utilization  demand_volatility
# 4        12.124              0.660                 0.817              0.137
# 9        13.592              0.600                 0.828              0.150
# 8        10.669              0.660                 0.762              0.130
# 19       10.582              0.480                 0.795              0.106
# 14       11.106              0.540                 0.821              0.134
# 13        9.962              0.600                 0.772              0.126
# 12        8.462              0.660                 0.706              0.128
# 3         8.785              0.480                 0.770              0.112
# 18       11.098              0.540                 0.725              0.165
# 17       10.350              0.600                 0.686              0.166

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 先加總分子、分母後再計算毛利率與容量利用率，避免直接平均月比率。
# - **預期輸出：** 20 列商品／服務 KPI 表。
# - **完成檢核：** 營收與毛利為金額；比率大致在 0 到 1 之間。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S04] 繪製成長－毛利績效矩陣

# %%
# 本格目的：用毛利、成長、利用率同時觀察組合位置
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=portfolio, x="growth_rate", y="gross_margin_rate",
    size="resource_utilization", hue="category", sizes=(60, 500), alpha=0.8,
)
plt.axhline(portfolio["gross_margin_rate"].median(), color="gray", linestyle="--")
plt.axvline(portfolio["growth_rate"].median(), color="gray", linestyle="--")
plt.title(f"{SELECTED_COMPANY} portfolio matrix (synthetic)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 38620 (\N{CJK UNIFIED IDEOGRAPH-96DC}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 33609 (\N{CJK UNIFIED IDEOGRAPH-8349}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 30010 (\N{CJK UNIFIED IDEOGRAPH-753A}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 25163 (\N{CJK UNIFIED IDEOGRAPH-624B}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 25423 (\N{CJK UNIFIED IDEOGRAPH-634F}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 38518 (\N{CJK UNIFIED IDEOGRAPH-9676}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 39636 (\N{CJK UNIFIED IDEOGRAPH-9AD4}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 39511 (\N{CJK UNIFIED IDEOGRAPH-9A57}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 32650 (\N{CJK UNIFIED IDEOGRAPH-7F8A}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 27611 (\N{CJK UNIFIED IDEOGRAPH-6BDB}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 27656 (\N{CJK UNIFIED IDEOGRAPH-6C08}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 35506 (\N{CJK UNIFIED IDEOGRAPH-8AB2}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 38272 (\N{CJK UNIFIED IDEOGRAPH-9580}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 23429 (\N{CJK UNIFIED IDEOGRAPH-5B85}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 22812 (\N{CJK UNIFIED IDEOGRAPH-591C}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\2679278398.py:10: UserWarning: Glyph 34269 (\N{CJK UNIFIED IDEOGRAPH-85DD}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38620 (\N{CJK UNIFIED IDEOGRAPH-96DC}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33609 (\N{CJK UNIFIED IDEOGRAPH-8349}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 30010 (\N{CJK UNIFIED IDEOGRAPH-753A}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25163 (\N{CJK UNIFIED IDEOGRAPH-624B}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25423 (\N{CJK UNIFIED IDEOGRAPH-634F}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38518 (\N{CJK UNIFIED IDEOGRAPH-9676}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 39636 (\N{CJK UNIFIED IDEOGRAPH-9AD4}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 39511 (\N{CJK UNIFIED IDEOGRAPH-9A57}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32650 (\N{CJK UNIFIED IDEOGRAPH-7F8A}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27611 (\N{CJK UNIFIED IDEOGRAPH-6BDB}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27656 (\N{CJK UNIFIED IDEOGRAPH-6C08}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 35506 (\N{CJK UNIFIED IDEOGRAPH-8AB2}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 31243 (\N{CJK UNIFIED IDEOGRAPH-7A0B}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 37329 (\N{CJK UNIFIED IDEOGRAPH-91D1}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24037 (\N{CJK UNIFIED IDEOGRAPH-5DE5}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20837 (\N{CJK UNIFIED IDEOGRAPH-5165}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38272 (\N{CJK UNIFIED IDEOGRAPH-9580}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 32769 (\N{CJK UNIFIED IDEOGRAPH-8001}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 23429 (\N{CJK UNIFIED IDEOGRAPH-5B85}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22812 (\N{CJK UNIFIED IDEOGRAPH-591C}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38291 (\N{CJK UNIFIED IDEOGRAPH-9593}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 34269 (\N{CJK UNIFIED IDEOGRAPH-85DD}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 以成長與毛利定位商品，再用氣泡大小表示資源利用。
# - **預期輸出：** 一張四象限氣泡圖。
# - **完成檢核：** 圖表只描述目前虛擬績效，不直接等同商品角色。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S05] 標準化六個分群特徵

# %%
# 本格目的：讓不同單位指標在距離計算中有相近權重
feature_cols = [
    "gross_margin_rate", "growth_rate", "resource_utilization",
    "repeat_rate", "satisfaction", "demand_volatility",
]
feature_matrix = portfolio[feature_cols].replace([np.inf, -np.inf], np.nan).fillna(portfolio[feature_cols].median())
scaler = StandardScaler()
X_scaled = scaler.fit_transform(feature_matrix)
scaled_df = pd.DataFrame(X_scaled, columns=feature_cols)
display(scaled_df.describe().round(2))
# Out:
#        gross_margin_rate  growth_rate  resource_utilization  repeat_rate  \
# count             20.000       20.000                20.000       20.000
# mean               0.000       -0.000                -0.000       -0.000
# std                1.030        1.030                 1.030        1.030
# min               -1.350       -1.470                -1.600       -1.580
# 25%               -0.670       -0.840                -0.670       -0.770
# 50%               -0.000       -0.190                -0.010        0.020
# 75%                0.670        0.870                 0.880        0.770
# max                1.350        1.480                 1.470        1.540
#
#        satisfaction  demand_volatility
# count        20.000             20.000
# mean          0.000              0.000
# std           1.030              1.030
# min          -1.540             -1.370
# 25%          -0.590             -0.770
# 50%          -0.060             -0.170
# 75%           0.660              0.320
# max           1.830              2.690

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 將毛利率、成長、利用率等不同尺度指標轉為平均 0、標準差約 1。
# - **預期輸出：** 標準化後描述統計。
# - **完成檢核：** 各特徵平均值接近 0；沒有缺失或無限值。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S06] 比較 k=3、4、5 的群數

# %%
# 本格目的：用 inertia、silhouette 與商業可解釋性選擇群數
score_rows = []
for k in range(3, 6):
    candidate = KMeans(n_clusters=k, random_state=20260714, n_init=10)
    labels = candidate.fit_predict(X_scaled)
    score_rows.append({"k": k, "inertia": candidate.inertia_, "silhouette": silhouette_score(X_scaled, labels)})
k_scores = pd.DataFrame(score_rows)
display(k_scores.round(3))

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(k_scores["k"], k_scores["inertia"], marker="o")
axes[0].set(title="Elbow", xlabel="k", ylabel="Inertia")
axes[1].plot(k_scores["k"], k_scores["silhouette"], marker="o")
axes[1].set(title="Silhouette", xlabel="k", ylabel="Score")
plt.tight_layout()
plt.show()
# Out:
#    k  inertia  silhouette
# 0  3   40.135       0.344
# 1  4   32.003       0.288
# 2  5   25.083       0.266

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 比較 k=3、4、5；inertia 越低、silhouette 越高通常較好，但仍需能被企業解釋。
# - **預期輸出：** 群數比較表與兩張折線。
# - **完成檢核：** 不因商品角色有四種就強迫 k=4。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S07] 建立 KMeans 並解讀群集輪廓

# %%
# 本格目的：使用得分較佳的群數建立可重現群集
BEST_K = int(k_scores.sort_values("silhouette", ascending=False).iloc[0]["k"])
kmeans = KMeans(n_clusters=BEST_K, random_state=20260714, n_init=10)
portfolio["cluster"] = kmeans.fit_predict(X_scaled)
print(f"本次採用 k={BEST_K}；群號沒有優劣順序。")

cluster_profile = portfolio.groupby("cluster")[feature_cols].mean().round(3)
display(cluster_profile)
sns.heatmap(cluster_profile, cmap="vlag", center=portfolio[feature_cols].mean().mean(), annot=True, fmt=".2f")
plt.title("Cluster profile on original KPI scale")
plt.tight_layout()
plt.show()
# Out:
# 本次採用 k=3；群號沒有優劣順序。
#          gross_margin_rate  growth_rate  resource_utilization  repeat_rate  \
# cluster
# 0                    0.570        0.065                 0.786        0.404
# 1                    0.564       -0.036                 0.634        0.243
# 2                    0.600       -0.078                 0.539        0.168
#
#          satisfaction  demand_volatility
# cluster
# 0               4.017              0.132
# 1               3.651              0.164
# 2               3.436              0.250

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 以固定 seed 建立群集，回到原始 KPI 平均值查看輪廓。
# - **預期輸出：** 群集輪廓表與熱圖。
# - **完成檢核：** cluster 0 只是一個編號，不是第一名。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S08] 用 PCA 呈現群集與變數方向

# %%
# 本格目的：把六個標準化指標壓縮到二維，方便觀察相似性
pca = PCA(n_components=2, random_state=20260714)
scores = pca.fit_transform(X_scaled)
portfolio["PC1"] = scores[:, 0]
portfolio["PC2"] = scores[:, 1]
print("前兩主成分解釋變異：", np.round(pca.explained_variance_ratio_, 3))

plt.figure(figsize=(9, 6))
sns.scatterplot(data=portfolio, x="PC1", y="PC2", hue="cluster", palette="tab10", s=110)
plt.title(f"{SELECTED_COMPANY} PCA map (synthetic)")
plt.tight_layout()
plt.show()

loadings = pd.DataFrame(pca.components_.T, index=feature_cols, columns=["PC1", "PC2"])
display(loadings.round(3))
# Out:
# 前兩主成分解釋變異： [0.732 0.179]
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\1620737631.py:11: UserWarning: Glyph 38620 (\N{CJK UNIFIED IDEOGRAPH-96DC}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\1620737631.py:11: UserWarning: Glyph 33609 (\N{CJK UNIFIED IDEOGRAPH-8349}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\AppData\Local\Temp\ipykernel_6384\1620737631.py:11: UserWarning: Glyph 30010 (\N{CJK UNIFIED IDEOGRAPH-753A}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 38620 (\N{CJK UNIFIED IDEOGRAPH-96DC}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 33609 (\N{CJK UNIFIED IDEOGRAPH-8349}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\enentutor\Desktop\AI_Projects\03_Teaching_教學課程\明志科技大學數據商業分析模組\AI驅動產品創新與市場應用培訓班\tools\m4_colab_package_builder\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 30010 (\N{CJK UNIFIED IDEOGRAPH-753A}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)
#                         PC1    PC2
# gross_margin_rate    -0.026  0.938
# growth_rate           0.470  0.055
# resource_utilization  0.471  0.112
# repeat_rate           0.468  0.114
# satisfaction          0.466 -0.007
# demand_volatility    -0.348  0.301

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** PCA 只用於壓縮與視覺探索，loadings 顯示哪些指標對主成分方向貢獻較大。
# - **預期輸出：** PCA 散點圖、解釋變異與 loadings。
# - **完成檢核：** 不得把 PCA 解釋變異當成模型準確率。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S09] 人工命名角色並加入供應風險

# %%
# 本格目的：把分群輪廓翻譯成可討論的商品角色
overall = portfolio[feature_cols].median()

def suggest_role(row):
    if row["growth_rate"] > overall["growth_rate"] and row["gross_margin_rate"] > overall["gross_margin_rate"]:
        return "成長／獲利候選"
    if row["resource_utilization"] > overall["resource_utilization"] and row["gross_margin_rate"] <= overall["gross_margin_rate"]:
        return "引流／容量管理候選"
    if row["repeat_rate"] > overall["repeat_rate"]:
        return "會員／加購候選"
    return "調整／限量測試候選"

portfolio["suggested_role"] = portfolio.apply(suggest_role, axis=1)
portfolio["supply_risk"] = np.where(
    (portfolio["resource_utilization"] > 0.85) & (portfolio["lead_time_days"] > portfolio["lead_time_days"].median()),
    "高：容量緊且前置期長", "一般",
)
display(portfolio[["offer", "cluster", "suggested_role", "gross_margin_rate", "growth_rate", "resource_utilization", "supply_risk"]].round(3))
# Out:
#          offer  cluster suggested_role  gross_margin_rate  growth_rate  \
# 0    手捏陶體驗-方案1        2      調整／限量測試候選              0.661       -0.087
# 1    羊毛氈課程-方案1        1      調整／限量測試候選              0.600       -0.038
# 2     金工入門-方案1        1        會員／加購候選              0.540       -0.014
# 3   老宅夜間工藝-方案1        0      引流／容量管理候選              0.480        0.038
# 4    手捏陶體驗-方案2        0        成長／獲利候選              0.660        0.078
# 5    羊毛氈課程-方案2        1      調整／限量測試候選              0.600       -0.086
# 6     金工入門-方案2        1      調整／限量測試候選              0.540       -0.049
# 7   老宅夜間工藝-方案2        1      調整／限量測試候選              0.480       -0.016
# 8    手捏陶體驗-方案3        0        成長／獲利候選              0.660        0.053
# 9    羊毛氈課程-方案3        0        成長／獲利候選              0.600        0.077
# 10    金工入門-方案3        2      調整／限量測試候選              0.540       -0.069
# 11  老宅夜間工藝-方案3        1      調整／限量測試候選              0.480       -0.025
# 12   手捏陶體驗-方案4        1        成長／獲利候選              0.660       -0.001
# 13   羊毛氈課程-方案4        0        成長／獲利候選              0.600        0.051
# 14    金工入門-方案4        0      引流／容量管理候選              0.540        0.085
# 15  老宅夜間工藝-方案4        1      調整／限量測試候選              0.480       -0.078
# 16   手捏陶體驗-方案5        1      調整／限量測試候選              0.660       -0.052
# 17   羊毛氈課程-方案5        1        成長／獲利候選              0.600       -0.008
# 18    金工入門-方案5        0      引流／容量管理候選              0.540        0.051
# 19  老宅夜間工藝-方案5        0      引流／容量管理候選              0.480        0.087
#
#     resource_utilization supply_risk
# 0                  0.530          一般
# 1                  0.620          一般
# 2                  0.683          一般
# 3                  0.770          一般
# 4                  0.817          一般
# 5                  0.556          一般
# 6                  0.622          一般
# 7                  0.679          一般
# 8                  0.762          一般
# 9                  0.828          一般
# 10                 0.548          一般
# 11                 0.621          一般
# 12                 0.706          一般
# 13                 0.772          一般
# 14                 0.821          一般
# 15                 0.534          一般
# 16                 0.631          一般
# 17                 0.686          一般
# 18                 0.725          一般
# 19                 0.795          一般

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 用透明規則產生角色候選，再要求小組依企業定位修改；這不是演算法標準答案。
# - **預期輸出：** 每個商品的群號、候選角色與供應風險。
# - **完成檢核：** 小組能引用至少一個 KPI 說明是否接受或修改角色。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ### [D2-S10] 匯出商品組合決策表並完成驗收

# %%
# 本格目的：保留可追溯指標，形成後續定價與上市課程輸入
portfolio["recommended_action"] = np.select(
    [
        portfolio["suggested_role"].eq("成長／獲利候選"),
        portfolio["suggested_role"].eq("引流／容量管理候選"),
        portfolio["suggested_role"].eq("會員／加購候選"),
    ],
    ["培養並做容量測試", "維持但設容量護欄", "設計加購／會員組合"],
    default="調整或限量驗證",
)
output_cols = [
    "offer_id", "offer", "cluster", "suggested_role", "recommended_action",
    "revenue", "gross_profit", "gross_margin_rate", "growth_rate",
    "resource_utilization", "repeat_rate", "supply_risk",
]
decision_output = portfolio[output_cols].sort_values(["cluster", "gross_profit"], ascending=[True, False])
display(decision_output.round(3))
decision_output.to_csv(OUTPUT_DIR / "Day2_商品組合決策表.csv", index=False, encoding="utf-8-sig")
# Out:
#     offer_id       offer  cluster suggested_role recommended_action  revenue  \
# 4   D2-01-05   手捏陶體驗-方案2        0        成長／獲利候選           培養並做容量測試  1575585
# 9   D2-01-10   羊毛氈課程-方案3        0        成長／獲利候選           培養並做容量測試  1617165
# 8   D2-01-09   手捏陶體驗-方案3        0        成長／獲利候選           培養並做容量測試  1322496
# 19  D2-01-20  老宅夜間工藝-方案5        0      引流／容量管理候選           維持但設容量護欄  1779030
# 14  D2-01-15    金工入門-方案4        0      引流／容量管理候選           維持但設容量護欄  1473120
# 13  D2-01-14   羊毛氈課程-方案4        0        成長／獲利候選           培養並做容量測試  1276800
# 3   D2-01-04  老宅夜間工藝-方案1        0      引流／容量管理候選           維持但設容量護欄  1264704
# 18  D2-01-19    金工入門-方案5        0      引流／容量管理候選           維持但設容量護欄  1087296
# 12  D2-01-13   手捏陶體驗-方案4        1        成長／獲利候選           培養並做容量測試   955182
# 17  D2-01-18   羊毛氈課程-方案5        1        成長／獲利候選           培養並做容量測試   898641
# 7   D2-01-08  老宅夜間工藝-方案2        1      調整／限量測試候選            調整或限量驗證  1015332
# 16  D2-01-17   手捏陶體驗-方案5        1      調整／限量測試候選            調整或限量驗證   671184
# 2   D2-01-03    金工入門-方案1        1        會員／加購候選          設計加購／會員組合   804807
# 1   D2-01-02   羊毛氈課程-方案1        1      調整／限量測試候選            調整或限量驗證   646758
# 6   D2-01-07    金工入門-方案2        1      調整／限量測試候選            調整或限量驗證   661626
# 11  D2-01-12  老宅夜間工藝-方案3        1      調整／限量測試候選            調整或限量驗證   611712
# 5   D2-01-06   羊毛氈課程-方案2        1      調整／限量測試候選            調整或限量驗證   475752
# 15  D2-01-16  老宅夜間工藝-方案4        1      調整／限量測試候選            調整或限量驗證   556888
# 10  D2-01-11    金工入門-方案3        2      調整／限量測試候選            調整或限量驗證   408446
# 0   D2-01-01   手捏陶體驗-方案1        2      調整／限量測試候選            調整或限量驗證   309792
#
#     gross_profit  gross_margin_rate  growth_rate  resource_utilization  \
# 4        1039780              0.660        0.078                 0.817
# 9         970299              0.600        0.077                 0.828
# 8         872808              0.660        0.053                 0.762
# 19        854174              0.480        0.087                 0.795
# 14        795584              0.540        0.085                 0.821
# 13        765700              0.600        0.051                 0.772
# 3         606945              0.480        0.038                 0.770
# 18        587334              0.540        0.051                 0.725
# 12        630436              0.660       -0.001                 0.706
# 17        539334              0.600       -0.008                 0.686
# 7         486988              0.480       -0.016                 0.679
# 16        443032              0.660       -0.052                 0.631
# 2         434850              0.540       -0.014                 0.683
# 1         387933              0.600       -0.038                 0.620
# 6         356979              0.540       -0.049                 0.622
# 11        293760              0.480       -0.025                 0.621
# 5         285348              0.600       -0.086                 0.556
# 15        267572              0.480       -0.078                 0.534
# 10        220614              0.540       -0.069                 0.548
# 0         204624              0.661       -0.087                 0.530
#
#     repeat_rate supply_risk
# 4         0.443          一般
# 9         0.427          一般
# 8         0.375          一般
# 19        0.451          一般
# 14        0.426          一般
# 13        0.366          一般
# 3         0.378          一般
# 18        0.367          一般
# 12        0.300          一般
# 17        0.307          一般
# 7         0.290          一般
# 16        0.250          一般
# 2         0.302          一般
# 1         0.226          一般
# 6         0.221          一般
# 11        0.225          一般
# 5         0.162          一般
# 15        0.145          一般
# 10        0.165          一般
# 0         0.171          一般

# %% [markdown]
# #### 程式碼說明（繁體中文）
#
# - **這段做了什麼：** 把分群、角色候選、KPI 與供應風險放在同一份可交接決策表。
# - **預期輸出：** 20 列決策表與輸出 CSV。
# - **完成檢核：** 每項行動均可回指 KPI，且仍保留人工修改空間。
# - **可修改處：** 只修改有 `TODO` 標記的參數；其他程式先完整執行，再觀察結果。

# %% [markdown]
# ## 當日學習驗收
#
# > 請先獨立作答；本 Notebook 不顯示答案。答案與解析收錄於教師版題庫。
#
# ### 第 1 題
#
# KMeans 屬於哪一類方法？
#
# - A. 監督式分類
# - B. 非監督式分群
# - C. 因果推論
# - D. 時間序列預測
#
# ### 第 2 題
#
# 進行 KMeans 前常要標準化，主要原因是？
#
# - A. 讓列數變多
# - B. 避免大尺度變數主導距離
# - C. 自動產生標籤
# - D. 保證群集具因果意義
#
# ### 第 3 題
#
# cluster 0 的正確解讀為何？
#
# - A. 一定是最差商品
# - B. 一定是第一名
# - C. 只是演算法給的群集編號
# - D. 表示零銷售
#
# ### 第 4 題
#
# 毛利額的基本計算是？
#
# - A. 售價＋單位成本
# - B. 銷量×（售價－單位成本）
# - C. 庫存天數÷售價
# - D. 營收×退貨率
#
# ### 第 5 題
#
# PCA 在本課的主要角色是？
#
# - A. 證明因果
# - B. 將多個指標壓縮後協助視覺探索
# - C. 預測明日需求
# - D. 自動決定促銷預算
#
# ### 第 6 題
#
# 商品組合中『引流角色』通常較重視什麼？
#
# - A. 吸引客流與轉換入口
# - B. 一定要最高毛利
# - C. 完全不需庫存
# - D. 只能在單一通路
#
# ### 第 7 題
#
# 分群後最重要的人工作業是？
#
# - A. 直接接受所有群集
# - B. 以企業情境檢查、命名並形成策略
# - C. 刪除小群
# - D. 把群號改成百分比
#
# ### 第 8 題
#
# 若服務型商品沒有實體庫存，較合適的替代指標是？
#
# - A. 容量利用率
# - B. 像素大小
# - C. 檔案名稱
# - D. 問卷題號
#
# ### 第 9 題
#
# 選擇群數 k 時，應怎麼做？
#
# - A. 永遠用 k=4
# - B. 只看顏色
# - C. 結合 elbow、輪廓與商業可解釋性
# - D. 等於欄位數
#
# ### 第 10 題
#
# 哪一項是正確的分群限制說明？
#
# - A. 群集代表市場真實客群
# - B. 換尺度或 k 後結果可能改變
# - C. 分群可直接估計促銷因果效果
# - D. 有 PCA 就不需資料清理
#
# ## 實作題
#
# 選擇一家公司，彙總商品／服務 KPI，使用至少 4 個標準化指標完成 KMeans 與 PCA，命名各群角色，提出『保留、培養、調整、驗證』四項行動；每項需引用至少一個數據指標。
#
# ### 評分規準
#
# - KPI 建立（20 分）：營收、毛利與容量／週轉計算正確
# - 分群流程（25 分）：有標準化、選 k 與可重跑模型
# - PCA 與視覺（15 分）：圖表清楚且解讀保守
# - 角色命名（20 分）：命名與群集輪廓一致
# - 組合行動（20 分）：行動兼顧企業命題與供應限制
#
# ### 繳交前檢查
#
# - 由上到下 Restart and Run All 無錯誤。
# - 所有圖表、指標與結論均顯示所選企業。
# - 結論明示虛擬資料、限制與下一步驗證。
# - 未將預測、相關或分群寫成因果證明。
